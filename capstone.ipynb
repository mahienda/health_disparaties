# %%
import pandas as pd
ipums_path = "nhis_00001.csv.gz"

# %%
df = pd.read_csv(ipums_path, low_memory=False)

df.head(3)
# Out:
#    YEAR  SERIAL  STRATA  PSU         NHISHID  PERNUM           NHISPID  \
# 0  2020       1     150   25  0002020H000002       1  0002020H00000210
# 1  2020       2     111   10  0002020H000003       1  0002020H00000310
# 2  2020       3     133    3  0002020H000004       1  0002020H00000410
#
#        HHX  SAMPWEIGHT  LONGWEIGHT  ...  HEIGHT  WEIGHT  BMICALC  HINOTCOVE  \
# 0  H000002    5946.002     17605.5  ...      66     230     37.1          1
# 1  H000003    6288.726         0.0  ...      71     180     25.1          1
# 2  H000004    6083.271         0.0  ...      64     155     26.6          1
#
#    HIPRIVATEE  HISTATEE  PCEMAILHPYR  PCACS  CVDDIAG  CVDTEST
# 0           2        10          NaN    NaN      1.0      1.0
# 1           2        10          NaN    NaN      0.0      0.0
# 2           2        10          NaN    NaN      0.0      0.0
#
# [3 rows x 30 columns]

# %%
rename_columns = {
    # 
    "YEAR": "year",
    "SERIAL": "serial_number",
    "STRATA": "sampling_strata",
    "PSU": "primary_sampling_unit",
    "NHISHID": "household_id",
    "PERNUM": "person_number",
    "NHISPID": "person_id",
    "HHX": "household_number",
    "RECTYPE": "record_type",         
    "ASTATFLG": "sample_adult_flag",   
    "CSTATFLG": "sample_child_flag",   
    # weights
    "SAMPWEIGHT": "sample_person_weight",
    "LONGWEIGHT": "longitudinal_weight",

    # demographics
    "SEX": "sex",
    "RACENEW": "race",
    "LANGHOMEOT": "non_english_at_home",

    # education
    "EDUC": "education_attainment",
    "MAXEDUC": "max_education_in_family",

    # health status 
    "HEALTH": "health_status",
    "HEIGHT": "height_inches",
    "WEIGHT": "weight_pounds",
    "BMICALC": "bmi",

    # insurance / access
    "HINOTCOVE": "health_insurance_coverage",
    "HIPRIVATEE": "private_insurance_coverage",
    "HISTATEE": "state_plan_insurance_coverage",
    "PCEMAILHPYR": "emailed_provider_past_12mo",
    "PCACS": "internet_access",

    # covid
    "CVDDIAG": "covid19_diagnosed_flag",
    "CVDTEST": "covid19_tested_flag",
}

# %%
df.rename(columns=rename_columns, inplace=True)

# %%
df.head(10)
# Out:
#    year  serial_number  sampling_strata  primary_sampling_unit  \
# 0  2020              1              150                     25
# 1  2020              2              111                     10
# 2  2020              3              133                      3
# 3  2020              4              139                     45
# 4  2020              5              130                     21
# 5  2020              6              131                      2
# 6  2020              7              128                     27
# 7  2020              8              123                     22
# 8  2020              9              122                     11
# 9  2020             10              149                     18
#
#      household_id  person_number         person_id household_serial  \
# 0  0002020H000002              1  0002020H00000210          H000002
# 1  0002020H000003              1  0002020H00000310          H000003
# 2  0002020H000004              1  0002020H00000410          H000004
# 3  0002020H000007              1  0002020H00000710          H000007
# 4  0002020H000009              1  0002020H00000910          H000009
# 5  0002020H000011              1  0002020H00001110          H000011
# 6  0002020H000014              1  0002020H00001410          H000014
# 7  0002020H000018              1  0002020H00001810          H000018
# 8  0002020H000019              1  0002020H00001910          H000019
# 9  0002020H000022              1  0002020H00002210          H000022
#
#    sample_weight  longitudinal_weight  ...  height_inches_no_shoes  \
# 0       5946.002             17605.50  ...                      66
# 1       6288.726                 0.00  ...                      71
# 2       6083.271                 0.00  ...                      64
# 3      11306.962                 0.00  ...                      67
# 4       6471.818             19317.18  ...                      66
# 5       3121.049             13087.37  ...                      96
# 6        754.476                 0.00  ...                      68
# 7       5120.231                 0.00  ...                      64
# 8       2682.171                 0.00  ...                      64
# 9       1738.221             16060.22  ...                      67
#
#    weight_pounds    bmi  no_health_insurance_flag  private_insurance_flag  \
# 0            230   37.1                         1                       2
# 1            180   25.1                         1                       2
# 2            155   26.6                         1                       2
# 3            240   37.6                         1                       2
# 4            180   29.0                         2                       1
# 5            996  996.0                         1                       2
# 6            160   24.3                         1                       2
# 7            160   27.5                         1                       1
# 8            160   27.5                         2                       1
# 9            155   24.3                         1                       2
#
#    state_plan_insurance_flag  emailed_provider_past_12mo  \
# 0                         10                         NaN
# 1                         10                         NaN
# 2                         10                         NaN
# 3                         10                         NaN
# 4                         10                         NaN
# 5                         10                         NaN
# 6                         10                         NaN
# 7                         10                         NaN
# 8                         10                         NaN
# 9                         10                         NaN
#
#    internet_access_flag  covid19_diagnosed_flag  covid19_tested_flag
# 0                   NaN                     1.0                  1.0
# 1                   NaN                     0.0                  0.0
# 2                   NaN                     0.0                  0.0
# 3                   NaN                     0.0                  0.0
# 4                   NaN                     1.0                  1.0
# 5                   NaN                     1.0                  1.0
# 6                   NaN                     1.0                  1.0
# 7                   NaN                     0.0                  0.0
# 8                   NaN                     1.0                  2.0
# 9                   NaN                     1.0                  1.0
#
# [10 rows x 30 columns]

# %%
print(df.columns)
# Out:
# Index(['year', 'serial_number', 'sampling_strata', 'primary_sampling_unit',
#        'household_id', 'person_number', 'person_id', 'household_serial',
#        'sample_weight', 'longitudinal_weight', 'PARTWEIGHT',
#        'sample_adult_flag', 'sample_child_flag', 'AGE', 'sex',
#        'race_omb_recode', 'non_english_at_home_flag', 'education_attainment',
#        'max_education_in_family', 'self_rated_health',
#        'height_inches_no_shoes', 'weight_pounds', 'bmi',
#        'no_health_insurance_flag', 'private_insurance_flag',
#        'state_plan_insurance_flag', 'emailed_provider_past_12mo',
#        'internet_access_flag', 'covid19_diagnosed_flag',
#        'covid19_tested_flag'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    year  serial_number  sampling_strata  primary_sampling_unit  \
# 0  2020              1              150                     25
# 1  2020              2              111                     10
# 2  2020              3              133                      3
# 3  2020              4              139                     45
# 4  2020              5              130                     21
# 5  2020              6              131                      2
# 6  2020              7              128                     27
# 7  2020              8              123                     22
# 8  2020              9              122                     11
# 9  2020             10              149                     18
#
#      household_id  person_number         person_id household_serial  \
# 0  0002020H000002              1  0002020H00000210          H000002
# 1  0002020H000003              1  0002020H00000310          H000003
# 2  0002020H000004              1  0002020H00000410          H000004
# 3  0002020H000007              1  0002020H00000710          H000007
# 4  0002020H000009              1  0002020H00000910          H000009
# 5  0002020H000011              1  0002020H00001110          H000011
# 6  0002020H000014              1  0002020H00001410          H000014
# 7  0002020H000018              1  0002020H00001810          H000018
# 8  0002020H000019              1  0002020H00001910          H000019
# 9  0002020H000022              1  0002020H00002210          H000022
#
#    sample_weight  longitudinal_weight  ...  height_inches_no_shoes  \
# 0       5946.002             17605.50  ...                      66
# 1       6288.726                 0.00  ...                      71
# 2       6083.271                 0.00  ...                      64
# 3      11306.962                 0.00  ...                      67
# 4       6471.818             19317.18  ...                      66
# 5       3121.049             13087.37  ...                      96
# 6        754.476                 0.00  ...                      68
# 7       5120.231                 0.00  ...                      64
# 8       2682.171                 0.00  ...                      64
# 9       1738.221             16060.22  ...                      67
#
#    weight_pounds    bmi  no_health_insurance_flag  private_insurance_flag  \
# 0            230   37.1                         1                       2
# 1            180   25.1                         1                       2
# 2            155   26.6                         1                       2
# 3            240   37.6                         1                       2
# 4            180   29.0                         2                       1
# 5            996  996.0                         1                       2
# 6            160   24.3                         1                       2
# 7            160   27.5                         1                       1
# 8            160   27.5                         2                       1
# 9            155   24.3                         1                       2
#
#    state_plan_insurance_flag  emailed_provider_past_12mo  \
# 0                         10                         NaN
# 1                         10                         NaN
# 2                         10                         NaN
# 3                         10                         NaN
# 4                         10                         NaN
# 5                         10                         NaN
# 6                         10                         NaN
# 7                         10                         NaN
# 8                         10                         NaN
# 9                         10                         NaN
#
#    internet_access_flag  covid19_diagnosed_flag  covid19_tested_flag
# 0                   NaN                     1.0                  1.0
# 1                   NaN                     0.0                  0.0
# 2                   NaN                     0.0                  0.0
# 3                   NaN                     0.0                  0.0
# 4                   NaN                     1.0                  1.0
# 5                   NaN                     1.0                  1.0
# 6                   NaN                     1.0                  1.0
# 7                   NaN                     0.0                  0.0
# 8                   NaN                     1.0                  2.0
# 9                   NaN                     1.0                  1.0
#
# [10 rows x 30 columns]

# %%
import pandas as pd
import numpy as np

# %%
# use partial/sample-adult if present...if not use the general weight
weight_col = "partial_sample_weight" if "partial_sample_weight" in df.columns else "sample_weight"

# %%
#Categorize labels

# %%
if "race_omb_recode" in df.columns:
    race_labels = {
        100: "White", 200: "Black", 300: "AIAN", 400: "Asian",
        510: "Other/Multiracial", 520: "Other", 541: "Multiracial",
        997: "Unknown-Refused", 998: "Unknown-NA", 999: "Unknown-DK"
    }

# %%
   df["race_grp"] = df["race_omb_recode"].map(race_labels).fillna("Other/Unknown")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'race_omb_recode'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df["race_grp"] = df["race_omb_recode"].map(race_labels).fillna("Other/Unknown")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'race_omb_recode'

# %%
csv_path = "adult24.csv"  
df = pd.read_csv(csv_path, low_memory=False)

print(df.head())
# Out:
#    RATCAT_A  INCTCFLG_A  IMPINCFLG_A  PPSU  PSTRAT  WLKLEISTC_A  WLKTRANTC_A  \
# 0         9           0            2     2     122          NaN          NaN
# 1         8           0            0     2     122         20.0          NaN
# 2         7           0            0     2     122         30.0          NaN
# 3        12           0            0     2     122         10.0          NaN
# 4        14           0            0     1     115          NaN          NaN
#
#    HISPALLP_A  RACEALLP_A  ANYDIFF_A  ...  LSATIS4_A  PHSTAT_A  HHSTAT_A  \
# 0           2           1          2  ...          1         1         1
# 1           2           1          2  ...          2         2         1
# 2           2           1          1  ...          1         2         1
# 3           2           1          1  ...          2         3         1
# 4           3           2          1  ...          2         3         1
#
#    INTV_MON  RECTYPE  IMPNUM_A  AVGNUMCIG_A     WTFA_A      HHX  POVRATTC_A
# 0         1       10         1           30   5780.565  H067658        2.82
# 1         1       10         1           20   3994.244  H076577        2.01
# 2         1       10         1           20   6636.755  H019335        1.90
# 3         1       10         1           01  13767.420  H012701        4.48
# 4         1       10         1          NaN  18880.030  H049678        6.37
#
# [5 rows x 630 columns]
